# %%
covid19 <- read.table("https://stat4ds.rwth-aachen.de/data/Covid19.dat", header=TRUE)
covid19

#table representing COVID19 cases, from day 1 to day 31
# Out:
#    day cases
# 1   1      16
# 2   2      24
# 3   3      30
# 4   4      53
# 5   5      80
# 6   6      98
# 7   7     164
# 8   8     214
# 9   9     279
# 10 10     423
# 11 11     647
# 12 12     937
# 13 13    1215
# 14 14    1629
# 15 15    1896
# 16 16    2234
# 17 17    3487
# 18 18    4226
# 19 19    7038
# 20 20   10442
# 21 21   15219
# 22 22   18747
# 23 23   24583
# 24 24   33404
# 25 25   44183
# 26 26   54453
# 27 27   68440
# 28 28   85356
# 29 29  103321
# 30 30  122653
# 31 31  140904

# %%
plot(covid19$day, covid19$cases, xlab="Day", ylab="cases", main="COVID 19 cases")

plot(density(covid19$cases))
# Out:
# Plot with title "COVID 19 cases"
# Plot with title "density(x = covid19$cases)"

# %%
mean(covid19$cases)

median(covid19$cases)
# Out:
# [1] 24077.26
# [1] 2234
