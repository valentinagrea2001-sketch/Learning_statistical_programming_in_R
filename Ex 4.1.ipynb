# %%
#STANDARD NORMAL DISTRIBUTION N(mu, sigma^2)

x <- seq(-6,6, by=0.1)
plot(x,dnorm(x, 0, 1), type="l", main="pdf of standard normal distribution", xlab="x", ylab="pdf")
# Out:
# Plot with title "pdf of standard normal distribution"

# %%
installed.packages("languageserver")
# Out:
#      Package LibPath Version Priority Depends Imports LinkingTo Suggests
#      Enhances License License_is_FOSS License_restricts_use OS_type Archs
#      MD5sum NeedsCompilation Built Published
