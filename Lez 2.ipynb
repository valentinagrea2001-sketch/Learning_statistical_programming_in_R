# %%
#FAMILIES OF DISTRIBUTIONS 

#runif(n, size)       : random uniform  experiment
#rbinom(n, size, p)   : random binomial experiment
#rpois(n, lambda)     : random poisson experiment

#if not r, but d: pdf
#if not r, but p: CDF

# %%
sample(1:20, 5, replace=FALSE)    #simple sampling with no repetitions
# Out:
# [1] 15 20 12  3  7

# %%
unif_exp <- runif(100, min=0, max=5)   #random uniform experiment
                                       #outputs a vector of values between min and max, same probability of being chosen

length(unif_exp)

unif_exp

head(unif_exp, 10)    #first 10 values of the list
tail(unif_exp, 10)    #last 10 entries of the list

mean(unif_exp)

plot(seq(1,100,by=1.0), unif_exp, xlab="number of experiment", ylab="outcome", main="outcomes of simulations")
# Out:
# [1] 100
#   [1] 1.2896065 3.8753161 4.8126057 2.4909601 1.5421201 2.9723148 2.6385243
#   [8] 3.5402165 0.7877020 3.7848420 0.2014903 1.6487978 0.4753822 1.0474096
#  [15] 1.5056123 2.4648879 0.8604461 3.8895310 4.0613116 3.0503674 1.6787948
#  [22] 1.4817217 3.5859936 4.4537387 3.9698606 3.1657743 4.6510905 0.2601209
#  [29] 2.5890321 1.4032861 1.2724162 2.2121918 1.5660427 4.0694926 2.2778450
#  [36] 0.9483460 0.9160038 1.1951462 4.4575567 0.6819670 0.0784988 4.7204856
#  [43] 2.8691160 1.4990177 3.3037385 2.3161358 4.0366495 1.6147874 0.8186470
#  [50] 2.0167910 2.9048273 4.8607067 3.0191135 2.6752921 1.0264933 1.2691698
#  [57] 1.0476712 2.3543410 0.6332511 3.5334379 2.8230025 4.2092529 2.6784009
#  [64] 2.3710564 1.6158546 3.9714077 0.4390648 2.1797119 2.9056797 3.3563143
#  [71] 3.4917380 4.5393180 0.6073189 2.2149958 2.5437290 0.2391701 0.5174376
#  [78] 0.3542937 1.5447936 4.8502966 3.5787602 3.6367273 1.0184551 0.9788910
#  [85] 4.0494526 4.5114363 4.6984750 1.6667073 2.4533370 0.6410274 1.8467574
#  [92] 0.7391050 4.0749216 2.9417698 3.3382569 3.3694696 4.6253432 1.0707614
#  [99] 4.5961165 2.5704228
#  [1] 1.289607 3.875316 4.812606 2.490960 1.542120 2.972315 2.638524 3.540216
#  [9] 0.787702 3.784842
#  [1] 1.846757 0.739105 4.074922 2.941770 3.338257 3.369470 4.625343 1.070761
#  [9] 4.596117 2.570423
# [1] 2.442331
# Plot with title "outcomes of simulations"

# %%
bin_exp <- rbinom(100, 20, 0.7)    #random binomial experiment
                                   #outputs a vector of successes over n simulations

                                   #n=100 simulations
                                   #for each simulation, size=20 Bernoulli trials: 0,1,0,0,0,1,1,0
                                   #prob=0.7 the probability of a success, i.e. 1, for a single Bernoulli trial

length(bin_exp)

bin_exp

mean(bin_exp)

sd(bin_exp)

plot(seq(1.0,100,by=1.0), bin_exp, type="l", xlab="number of experiment", ylab="successes", main="plot of successes for 100 binomial experiments")

y <- seq(1,100, by=1.0)
plot(y, dbinom(y, 20, 0.7), type="b", main="pdf of Binom(20,0.7)")
# Out:
# [1] 100
#   [1] 13 11 12 17 14 13 13 15 13 14 11 15 13 14 15 16 17 17 16 11 11 13 19 17 15
#  [26] 18 14 12 14 16 14 17 14 12 17 14 14 15 16 16 12 16 14 15 13 14 14 17  8 14
#  [51] 12 16 17 11 17 18 12 14 15 15 14 17 11 10 13 13 13 16 14 15 17 15 15 15 12
#  [76] 14 15 16 15 14 16 17 12 15 13 15 11 12 16 11 16 14 16 12 13 17 13 15 13 17
# [1] 14.3
# [1] 2.062165
# Plot with title "plot of successes for 100 binomial experiments"
# Plot with title "pdf of Binom(20,0.7)"

# %%
ppois(3, 10)    #CDF for a poisson process F_{lambda=10}(x=3)=P(X<=3)

dpois(3, 10)    #pmf/pdf for a poisson process f_{lambda=10}(x=3)=P(X=3)

poi_exp <- rpois(100, 10)     #random poisson experiment, when at a time event occurs 10 times
                              #output a vector of occuring events in 100 simulations on time intervals of same length          
plot(seq(1,100,by=1.0), poi_exp, type="l", main="events occurring in same time interval", xlab="simulation", ylab="number of events")  


y <- seq(1, 100, by=1.0)            #plot pmf
plot(y, dpois(y, 10), type="b", main="probability density function for Poi(10)", xlab="x", ylab="pdf")
# Out:
# [1] 0.01033605
# [1] 0.007566655
# Plot with title "events occurring in same time interval"
# Plot with title "probability density function for Poi(10)"

# %%
rnorm(100, mean=0, sd=1)
# Out:
#   [1] -0.54824071  1.28729296  0.32657142 -1.41367192  0.26928730  0.52281777
#   [7]  0.42879694 -0.08174283  1.00173697  2.07490970  0.61555309 -0.34527261
#  [13] -1.49747450  2.09849671  1.25598726  1.22962599 -0.08586665  0.53608552
#  [19]  1.16000999 -0.71826623 -0.20578106  0.15987234  0.56601553  0.31973138
#  [25] -1.09140803 -1.34420065  0.60353686  1.89688615  2.31029816 -0.11789053
#  [31]  0.46709632 -0.70366345  2.32016743  0.09456097  0.48463312 -0.14996464
#  [37] -0.08820234 -1.56183250  1.45403108 -0.36355536 -1.22575083 -2.08066232
#  [43]  1.07780707  1.15564273 -1.59130717 -0.55216273 -0.22873400  0.55445485
#  [49]  1.66460370  1.07197924 -1.01973829 -1.39992219 -0.09205849 -0.72448878
#  [55] -0.31040509  0.88527675  0.03085541 -0.94162917 -0.42497891  0.26726640
#  [61]  0.57227695  1.27675365 -0.70394995 -2.30188899 -0.23944873  0.36591115
#  [67]  1.75871070 -2.00960197 -0.97479323  1.14869158  0.80351038  1.86913362
#  [73]  0.17578217  1.10460592  0.01217001 -1.50407936  0.88204930  2.35183570
#  [79]  1.50448138  1.55770610  1.41211653 -0.49844941 -0.14624235  1.37148672
#  [85] -0.38368797  1.46984092 -0.28028306  0.19472133  0.21173947 -0.19017911
#  [91] -0.55294395 -1.53550696 -0.37112012  0.88941233  0.00456188  0.27250580
#  [97] -0.49061220  0.30077683 -0.16960009  0.74745925
